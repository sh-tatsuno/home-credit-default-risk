# %%
import pandas as pd
import numpy as np
import random
import copy

from lightgbm import LGBMClassifier
import lightgbm as lgbm
from tqdm import tqdm_notebook as tqdm

from sklearn.metrics import roc_auc_score, precision_recall_curve, roc_curve
from sklearn.model_selection import KFold
import matplotlib.pyplot as plt
import seaborn as sns
import gc
from utils.utils import *

pd.options.display.max_columns = None
# %matplotlib inline

# %%
all_data = pd.read_pickle('edit/fixed_data/all_data.pkl')
buro = pd.read_pickle('edit/fixed_data/buro.pkl')
cc_bal = pd.read_pickle('edit/fixed_data/cc_bal.pkl')
inst = pd.read_pickle('edit/fixed_data/inst.pkl')
pos = pd.read_pickle('edit/fixed_data/pos.pkl')
prev = pd.read_pickle('edit/fixed_data/prev.pkl')

# %%
def run(model=None, submit=None):
    merged = DataMerger([all_data, buro, cc_bal, inst, pos, prev], 'SK_ID_CURR')
    FoldSubmit(merged, index_cols, model, submit)

# %%
# base model
clf = LGBMClassifier(
            nthread=4,
            n_estimators=10000,
            learning_rate=0.02,
            num_leaves=32,
            colsample_bytree=0.9497036,
            subsample=0.8715623,
            max_depth=8,
            reg_alpha=0.04,
            reg_lambda=0.073,
            min_split_gain=0.0222415,
            min_child_weight=40,
            random_state=seed,
            silent=-1,
            verbose=-1, )

# %%
merged = DataMerger([all_data, buro, cc_bal, inst, pos, prev], 'SK_ID_CURR')
clf_set =  FoldSubmit(merged, index_cols, clf, return_clf=True)
feat_cols = merged.drop(index_cols,axis=1).columns
# Out:
# 100%|██████████| 6/6 [00:23<00:00,  4.45s/it]
# Training until validation scores don't improve for 150 rounds.
# [100]	training's auc: 0.7572	valid_1's auc: 0.750343
# [200]	training's auc: 0.781176	valid_1's auc: 0.767766
# [300]	training's auc: 0.799615	valid_1's auc: 0.779381
# [400]	training's auc: 0.812122	valid_1's auc: 0.784964
# [500]	training's auc: 0.822272	valid_1's auc: 0.787902
# [600]	training's auc: 0.830675	valid_1's auc: 0.789539
# [700]	training's auc: 0.838401	valid_1's auc: 0.790743
# [800]	training's auc: 0.845329	valid_1's auc: 0.791582
# [900]	training's auc: 0.851975	valid_1's auc: 0.792091
# [1000]	training's auc: 0.857867	valid_1's auc: 0.792588
# [1100]	training's auc: 0.863606	valid_1's auc: 0.792994
# [1200]	training's auc: 0.869159	valid_1's auc: 0.792978
# Early stopping, best iteration is:
# [1098]	training's auc: 0.863471	valid_1's auc: 0.793004
# Fold  1 AUC : 0.793004
# Training until validation scores don't improve for 150 rounds.
# [100]	training's auc: 0.756751	valid_1's auc: 0.739912
# [200]	training's auc: 0.781332	valid_1's auc: 0.758516
# [300]	training's auc: 0.80012	valid_1's auc: 0.770847
# [400]	training's auc: 0.812796	valid_1's auc: 0.776114
# [500]	training's auc: 0.823259	valid_1's auc: 0.779192
# [600]	training's auc: 0.831751	valid_1's auc: 0.78119
# [700]	training's auc: 0.839564	valid_1's auc: 0.782717
# [800]	training's auc: 0.84676	valid_1's auc: 0.783464
# [900]	training's auc: 0.853207	valid_1's auc: 0.78407
# [1000]	training's auc: 0.859245	valid_1's auc: 0.784472
# [1100]	training's auc: 0.864929	valid_1's auc: 0.785018
# [1200]	training's auc: 0.870519	valid_1's auc: 0.785046
# [1300]	training's auc: 0.875933	valid_1's auc: 0.785355
# [1400]	training's auc: 0.880823	valid_1's auc: 0.785547
# [1500]	training's auc: 0.885218	valid_1's auc: 0.785484
# [1600]	training's auc: 0.889709	valid_1's auc: 0.785599
# [1700]	training's auc: 0.893918	valid_1's auc: 0.785677
# [1800]	training's auc: 0.898122	valid_1's auc: 0.785766
# [1900]	training's auc: 0.902402	valid_1's auc: 0.78584
# [2000]	training's auc: 0.906046	valid_1's auc: 0.785845
# Early stopping, best iteration is:
# [1941]	training's auc: 0.903828	valid_1's auc: 0.785945
# Fold  2 AUC : 0.785945
# Training until validation scores don't improve for 150 rounds.
# [100]	training's auc: 0.
# Training until validation scores don't improve for 150 rounds.
# [100]	training's auc: 0.755876	valid_1's auc: 0.746643
# [200]	training's auc: 0.78347	valid_1's auc: 0.767184
# [300]	training's auc: 0.801832	valid_1's auc: 0.778332
# [400]	training's auc: 0.814034	valid_1's auc: 0.78334
# [500]	training's auc: 0.823709	valid_1's auc: 0.786271
# [600]	training's auc: 0.83229	valid_1's auc: 0.787921
# [700]	training's auc: 0.839885	valid_1's auc: 0.789083
# [800]	training's auc: 0.846875	valid_1's auc: 0.789794
# [900]	training's auc: 0.853351	valid_1's auc: 0.790289
# [1000]	training's auc: 0.859367	valid_1's auc: 0.790637
# [1100]	training's auc: 0.864926	valid_1's auc: 0.790875
# [1200]	training's auc: 0.870025	valid_1's auc: 0.790993
# [1300]	training's auc: 0.875082	valid_1's auc: 0.79101
# [1400]	training's auc: 0.880012	valid_1's auc: 0.791031
# [1500]	training's auc: 0.88475	valid_1's auc: 0.790909
# Early stopping, best iteration is:
# [1434]	training's auc: 0.881851	valid_1's auc: 0.791125
# Fold  4 AUC : 0.791125
# Total AUC : 0.790204

# %%
def FoldSubmit_base(all_data, index_cols, model = None, submit=None, return_clf = False):
    np.random.seed(seed)
    folds = KFold(n_splits=4, shuffle=True, random_state=seed)
    data = all_data[all_data.TEST==0]
    y = data.TARGET
    data = data.drop(index_cols,axis=1)
    test = all_data[all_data.TEST==1].drop(index_cols,axis=1)
    total_score=[]
    clf_set=[]

    sub_preds = np.zeros(test.shape[0])

    for n_fold, (trn_idx, val_idx) in enumerate(folds.split(data)):
        trn_x, trn_y = data.iloc[trn_idx], y.iloc[trn_idx]
        val_x, val_y = data.iloc[val_idx], y.iloc[val_idx]

        if model == None:
            clf = LGBMClassifier(
                n_estimators=300,
                learning_rate=0.03,
                num_leaves=30,
                colsample_bytree=.8,
                subsample=.9,
                max_depth= 7,
                reg_alpha=.1,
                reg_lambda=.1,
                min_split_gain=.01,
                min_child_weight=2,
                random_state=seed,
                silent=True,
                verbose=-1,
            )
        else:
            clf = model
        
        clf.fit(trn_x, trn_y,
                eval_set= [(trn_x, trn_y), (val_x, val_y)],
                eval_class_weight = [{0: np.sum(trn_y) , 1: len(trn_y)-np.sum(trn_y)}, {0:np.sum(val_y), 1:len(val_y)-np.sum(val_y)}], 
                eval_metric='auc', 
                verbose=100, 
                early_stopping_rounds=150
               )


        oof_preds = clf.predict_proba(val_x, num_iteration=clf.best_iteration_)[:, 1]
        sub_preds += clf.predict_proba(test, num_iteration=clf.best_iteration_)[:, 1] / folds.n_splits

        auc_score = roc_auc_score(val_y, oof_preds)
        print('Fold %2d AUC : %.6f' % (n_fold + 1, auc_score))

        total_score.append(auc_score)
        if return_clf: clf_set.append(copy.deepcopy(clf))

    print('Mean AUC : %.6f' % (np.mean(total_score)))
    print('Std AUC : %.6f' % (np.std(total_score)))

    if submit!=None:
        submit_data = pd.DataFrame(np.c_[all_data[all_data.TEST==1]['SK_ID_CURR'].values.astype('int32'),sub_preds],
             columns=['SK_ID_CURR','TARGET'])
        submit_data['SK_ID_CURR'] = submit_data['SK_ID_CURR'].astype('int')
        submit_data['TARGET'] = submit_data['TARGET'].astype('float32')
        submit_data.to_csv('csv/'+submit, index=None, float_format='%.8f')

    if return_clf: return clf_set

    return

# %%
merged = DataMerger([all_data, buro, cc_bal, inst, pos, prev], 'SK_ID_CURR')
# Out:
# 100%|██████████| 6/6 [00:33<00:00,  6.68s/it]

# %%
clf_set = FoldSubmit_base(merged, index_cols, clf, return_clf=True)
# Out:
# Training until validation scores don't improve for 150 rounds.
# [100]	training's auc: 0.754741	valid_1's auc: 0.744837
# [200]	training's auc: 0.782478	valid_1's auc: 0.765954
# [300]	training's auc: 0.801063	valid_1's auc: 0.778692
# [400]	training's auc: 0.813384	valid_1's auc: 0.784409
# [500]	training's auc: 0.823198	valid_1's auc: 0.787804
# [600]	training's auc: 0.8313	valid_1's auc: 0.789468
# [700]	training's auc: 0.838955	valid_1's auc: 0.790598
# [800]	training's auc: 0.846012	valid_1's auc: 0.791458
# [900]	training's auc: 0.852679	valid_1's auc: 0.792076
# [1000]	training's auc: 0.858569	valid_1's auc: 0.792447
# [1100]	training's auc: 0.864228	valid_1's auc: 0.792707
# [1200]	training's auc: 0.869666	valid_1's auc: 0.79294
# [1300]	training's auc: 0.874806	valid_1's auc: 0.793136
# [1400]	training's auc: 0.87941	valid_1's auc: 0.793119
# [1500]	training's auc: 0.884148	valid_1's auc: 0.793277
# [1600]	training's auc: 0.888924	valid_1's auc: 0.793452
# [1700]	training's auc: 0.893234	valid_1's auc: 0.793317
# Early stopping, best iteration is:
# [1583]	training's auc: 0.888149	valid_1's auc: 0.793487
# Fold  1 AUC : 0.793487
# Finished loading model, total used 1583 iterations
# Training until validation scores don't improve for 150 rounds.
# [100]	training's auc: 0.755548	valid_1's auc: 0.742556
# [200]	training's auc: 0.782882	valid_1's auc: 0.764521
# [300]	training's auc: 0.801815	valid_1's auc: 0.776741
# [400]	training's auc: 0.814131	valid_1's auc: 0.781671
# [500]	training's auc: 0.823963	valid_1's auc: 0.784842
# [600]	training's auc: 0.83212	valid_1's auc: 0.786672
# [700]	training's auc: 0.839814	valid_1's auc: 0.787874
# [800]	training's auc: 0.846778	valid_1's auc: 0.788702
# [900]	training's auc: 0.853147	valid_1's auc: 0.789585
# [1000]	training's auc: 0.859249	valid_1's auc: 0.790269
# [1100]	training's auc: 0.865047	valid_1's auc: 0.790695
# [1200]	training's auc: 0.87046	valid_1's auc: 0.790961
# [1300]	training's auc: 0.875785	valid_1's auc: 0.791152
# [1400]	training's auc: 0.880531	valid_1's auc: 0.791189
# [1500]	training's auc: 0.885035	valid_1's auc: 0.791188
# [1600]	training's auc: 0.889492	valid_1's auc: 0.791392

# %%
feat_cols = merged.drop(index_cols,axis=1).columns

# %%
all_data = pd.read_pickle('edit/tmp_data/all_dataX2.pkl')
merged = DataMerger([all_data, buro, cc_bal, inst, pos, prev], 'SK_ID_CURR')
clf_set2 = FoldSubmit_base(merged, index_cols, clf, return_clf=True)

# %%
len(feat_cols)
# Out:
# 620

# %%
for i in range(4):
    if i == 0:
        data = pd.DataFrame([list(feat_cols),clf_set[i].feature_importances_.tolist()], index=['feature','score_'+str(i)]).T
    else:
        data =data.merge(pd.DataFrame([list(feat_cols),clf_set[i].feature_importances_.tolist()], index=['feature','score_'+str(i)]).T, on='feature')

# %%
data
# Out:
#                                    feature score_0 score_1 score_2 score_3
# 0                              AMT_ANNUITY     595     595     595     595
# 1                               AMT_CREDIT     326     326     326     326
# 2                          AMT_GOODS_PRICE     334     334     334     334
# 3                         AMT_INCOME_TOTAL     185     185     185     185
# 4                AMT_REQ_CREDIT_BUREAU_DAY       1       1       1       1
# 5               AMT_REQ_CREDIT_BUREAU_HOUR       0       0       0       0
# 6                AMT_REQ_CREDIT_BUREAU_MON      22      22      22      22
# 7                AMT_REQ_CREDIT_BUREAU_QRT      62      62      62      62
# 8               AMT_REQ_CREDIT_BUREAU_WEEK      12      12      12      12
# 9               AMT_REQ_CREDIT_BUREAU_YEAR     109     109     109     109
# 10                          APARTMENTS_AVG      74      74      74      74
# 11                         APARTMENTS_MEDI      72      72      72      72
# 12                         APARTMENTS_MODE      76      76      76      76
# 13                        BASEMENTAREA_AVG      79      79      79      79
# 14                       BASEMENTAREA_MEDI      45      45      45      45
# 15                       BASEMENTAREA_MODE      81      81      81      81
# 16                            CNT_CHILDREN      27      27      27      27
# 17                         CNT_FAM_MEMBERS      40      40      40      40
# 18                             CODE_GENDER     213     213     213     213
# 19                          COMMONAREA_AVG      75      75      75      75
# 20                         COMMONAREA_MEDI      66      66      66      66
# 21                         COMMONAREA_MODE      53      53      53      53
# 22                              DAYS_BIRTH     809     809     809     809
# 23                           DAYS_EMPLOYED     683     683     683     683
# 24                         DAYS_ID_PUBLISH     461     461     461     461
# 25                  DAYS_LAST_PHONE_CHANGE     229     229     229     229
# 26                       DAYS_REGISTRATION     473     473     473     473
# 27                DEF_30_CNT_SOCIAL_CIRCLE      87      87      87      87
# 28                DEF_60_CNT_SOCIAL_CIRCLE      66      66      66      66
# 29                           ELEVATORS_AVG      36      36      36      36
# ..                                     ...     ...     ...     ...     ...
# 590  APPROVED_HOUR_APPR_PROCESS_START_MEAN     188     188     188     188
# 591         APPROVED_RATE_DOWN_PAYMENT_MIN     105     105     105     105
# 592         APPROVED_RATE_DOWN_PAYMENT_MAX     138     138     138     138
# 593        APPROVED_RATE_DOWN_PAYMENT_MEAN     127     127     127     127
# 594             APPROVED_DAYS_DECISION_MIN     157     157     157     157
# 595             APPROVED_DAYS_DECISION_MAX     323     323     323     323
# 596            APPROVED_DAYS_DECISION_MEAN     201     201     201     201
# 597              APPROVED_CNT_PAYMENT_MEAN     457     457     457     457
# 598               APPROVED_CNT_PAYMENT_SUM     241     241     241     241
# 599                REFUSED_AMT_ANNUITY_MAX     110     110     110     110
# 600               REFUSED_AMT_ANNUITY_MEAN      92      92      92      92
# 601           REFUSED_AMT_APPLICATION_MEAN      72      72      72      72
# 602                 REFUSED_AMT_CREDIT_MAX      84      84      84      84
# 603                REFUSED_AMT_CREDIT_MEAN      67      67      67      67
# 604            REFUSED_APP_CREDIT_PERC_MAX      72      72      72      72
# 605           REFUSED_APP_CREDIT_PERC_MEAN     111     111     111     111
# 606           REFUSED_AMT_DOWN_PAYMENT_MAX      29      29      29      29
# 607          REFUSED_AMT_DOWN_PAYMENT_MEAN      15      15      15      15
# 608            REFUSED_AMT_GOODS_PRICE_MAX      85      85      85      85
# 609           REFUSED_AMT_GOODS_PRICE_MEAN      66      66      66      66
# 610    REFUSED_HOUR_APPR_PROCESS_START_MAX      64      64      64      64
# 611   REFUSED_HOUR_APPR_PROCESS_START_MEAN      98      98      98      98
# 612          REFUSED_RATE_DOWN_PAYMENT_MIN      21      21      21      21
# 613          REFUSED_RATE_DOWN_PAYMENT_MAX      42      42      42      42
# 614         REFUSED_RATE_DOWN_PAYMENT_MEAN      21      21      21      21
# 615              REFUSED_DAYS_DECISION_MIN     149     149     149     149
# 616              REFUSED_DAYS_DECISION_MAX     201     201     201     201
# 617             REFUSED_DAYS_DECISION_MEAN     120     120     120     120
# 618               REFUSED_CNT_PAYMENT_MEAN      86      86      86      86
# 619                REFUSED_CNT_PAYMENT_SUM      91      91      91      91
#
# [620 rows x 5 columns]

# %%
# イテレーション回す用のやつ
# 特徴量選択・うまくいったら残す
# columns, picked(チェックしてよかった), used(現在の全部), drop(不要)
# でそれぞれto_pickle

# %%
clf_set
# Out:
# [LGBMClassifier(boosting_type='gbdt', class_weight=None,
#          colsample_bytree=0.9497036, learning_rate=0.02, max_depth=8,
#          min_child_samples=20, min_child_weight=40,
#          min_split_gain=0.0222415, n_estimators=10000, n_jobs=-1, nthread=4,
#          num_leaves=32, objective=None, random_state=1001, reg_alpha=0.04,
#          reg_lambda=0.073, silent=-1, subsample=0.8715623,
#          subsample_for_bin=200000, subsample_freq=1, verbose=-1),
#  LGBMClassifier(boosting_type='gbdt', class_weight=None,
#          colsample_bytree=0.9497036, learning_rate=0.02, max_depth=8,
#          min_child_samples=20, min_child_weight=40,
#          min_split_gain=0.0222415, n_estimators=10000, n_jobs=-1, nthread=4,
#          num_leaves=32, objective=None, random_state=1001, reg_alpha=0.04,
#          reg_lambda=0.073, silent=-1, subsample=0.8715623,
#          subsample_for_bin=200000, subsample_freq=1, verbose=-1),
#  LGBMClassifier(boosting_type='gbdt', class_weight=None,
#          colsample_bytree=0.9497036, learning_rate=0.02, max_depth=8,
#          min_child_samples=20, min_child_weight=40,
#          min_split_gain=0.0222415, n_estimators=10000, n_jobs=-1, nthread=4,
#          num_leaves=32, objective=None, random_state=1001, reg_alpha=0.04,
#          reg_lambda=0.073, silent=-1, subsample=0.8715623,
#          subsample_for_bin=200000, subsample_freq=1, verbose=-1),
#  LGBMClassifier(boosting_type='gbdt', class_weight=None,
#          colsample_bytree=0.9497036, learning_rate=0.02, max_depth=8,
#          min_child_samples=20, min_child_weight=40,
#          min_split_gain=0.0222415, n_estimators=10000, n_jobs=-1, nthread=4,
#          num_leaves=32, objective=None, random_state=1001, reg_alpha=0.04,
#          reg_lambda=0.073, silent=-1, subsample=0.8715623,
#          subsample_for_bin=200000, subsample_freq=1, verbose=-1)]

# %%
all_data = pd.read_pickle('edit/tmp_data/all_dataX.pkl')
merged = DataMerger([all_data, buro, cc_bal, inst, pos, prev], 'SK_ID_CURR')
SK_ID = pd.read_pickle('./edit/tmp_data/choice_SK_ID.pkl')
merged = SK_ID.to_frame().merge(merged, how='left', on='SK_ID_CURR')
FoldSubmit(merged, index_cols, clf, submit='180720-2.csv')
# Out:
# 100%|██████████| 6/6 [00:25<00:00,  4.83s/it]
# Training until validation scores don't improve for 150 rounds.
# [100]	training's auc: 0.755755	valid_1's auc: 0.750502
# [200]	training's auc: 0.783795	valid_1's auc: 0.771823
# [300]	training's auc: 0.802442	valid_1's auc: 0.784341
# [400]	training's auc: 0.81501	valid_1's auc: 0.790659
# [500]	training's auc: 0.824775	valid_1's auc: 0.79401
# [600]	training's auc: 0.833719	valid_1's auc: 0.795995
# [700]	training's auc: 0.842022	valid_1's auc: 0.797109
# [800]	training's auc: 0.849101	valid_1's auc: 0.797917
# Training until validation scores don't improve for 150 rounds.
# [100]	training's auc: 0.758355	valid_1's auc: 0.74187
# [200]	training's auc: 0.78093	valid_1's auc: 0.756243
# [300]	training's auc: 0.798973	valid_1's auc: 0.76709
# [400]	training's auc: 0.810908	valid_1's auc: 0.772257
# [500]	training's auc: 0.820212	valid_1's auc: 0.775331
# [600]	training's auc: 0.828751	valid_1's auc: 0.777443
# [700]	training's auc: 0.836456	valid_1's auc: 0.778928
# [800]	training's auc: 0.843354	valid_1's auc: 0.779887
# [900]	training's auc: 0.8498	valid_1's auc: 0.780519
# [1000]	training's auc: 0.855981	valid_1's auc: 0.781108
# [1100]	training's auc: 0.861433	valid_1's auc: 0.781643
# [1200]	training's auc: 0.867008	valid_1's auc: 0.781992
# [1300]	training's auc: 0.87211	valid_1's auc: 0.782146
# [1400]	training's auc: 0.877138	valid_1's auc: 0.782223
# [1500]	training's auc: 0.881813	valid_1's auc: 0.782502
# [1600]	training's auc: 0.88626	valid_1's auc: 0.782642
# [1700]	training's auc: 0.89053	valid_1's auc: 0.782576
# Early stopping, best iteration is:
# [1622]	training's auc: 0.887222	valid_1's auc: 0.78269
# Fold  3 AUC : 0.782690
# Training until validation scores don't improve for 150 rounds.
# [100]	training's auc: 0.758264	valid_1's auc: 0.746431
# [200]	training's auc: 0.780425	valid_1's auc: 0.761817
# [300]	training's auc: 0.798379	valid_1's auc: 0.773198
# [400]	training's auc: 0.810285	valid_1's auc: 0.778293
# [500]	training's auc: 0.819792	valid_1's auc: 0.781112
# [600]	training's auc: 0.828047	valid_1's auc: 0.782708
# [700]	training's auc: 0.835633	valid_1's auc: 0.784145
# [800]	training's auc: 0.842598	valid_1's auc: 0.784801
# [900]	training's auc: 0.848953	valid_1's auc: 0.785391
# [1000]	training's auc: 0.854879	valid_1's auc: 0.785468
# [1100]	training's auc: 0.860363	valid_1's auc: 0.785755
# [1200]	training's auc: 0.865678	valid_1's auc: 0.786104
# [1300]	training's auc: 0.870735	valid_1's auc: 0.786295
# [1400]	training's auc: 0.875615	valid_1's auc: 0.786406
# [1500]	training's auc: 0.880445	valid_1's auc: 0.786481
# [1600]	training's auc: 0.885008	valid_1's auc: 0.786544
# [1700]	training's auc: 0.889173	valid_1's auc: 0.786459
# Early stopping, best iteration is:
# [1562]	training's auc: 0.883321	valid_1's auc: 0.786624
# Fold  4 AUC : 0.786624
# Total AUC : 0.785744

# %%
def FoldSubmit_base(all_data, index_cols, model = None, submit=None, return_clf = False):
    np.random.seed(seed)
    folds = KFold(n_splits=4, shuffle=True, random_state=seed)
    data = all_data[all_data.TEST==0]
    y = data.TARGET
    data = data.drop(index_cols,axis=1)
    test = all_data[all_data.TEST==1].drop(index_cols,axis=1)
    total_score=0
    clf_set=[]

    sub_preds = np.zeros(test.shape[0])

    for n_fold, (trn_idx, val_idx) in enumerate(folds.split(data)):
        trn_x, trn_y = data.iloc[trn_idx], y.iloc[trn_idx]
        val_x, val_y = data.iloc[val_idx], y.iloc[val_idx]

        if model == None:
            clf = LGBMClassifier(
                n_estimators=300,
                learning_rate=0.03,
                num_leaves=30,
                colsample_bytree=.8,
                subsample=.9,
                max_depth= 7,
                reg_alpha=.1,
                reg_lambda=.1,
                min_split_gain=.01,
                min_child_weight=2,
                random_state=seed,
                silent=True,
                verbose=-1,
            )
        else:
            clf = model

        clf.fit(trn_x, trn_y,
                eval_set= [(trn_x, trn_y), (val_x, val_y)],
                eval_class_weight = [np.sum(val_y), len(val_y) - np.sum(val_y)] # inverse rate, 0 : 1
                eval_metric='auc', 
                verbose=100, 
                early_stopping_rounds=150
               )


        oof_preds = clf.predict_proba(val_x.iloc[arrange_inds], num_iteration=clf.best_iteration_)[:, 1]
        sub_preds += clf.predict_proba(test, num_iteration=clf.best_iteration_)[:, 1] / folds.n_splits

        auc_score = roc_auc_score(val_y.iloc[arrange_inds], oof_preds)
        print('Fold %2d AUC : %.6f' % (n_fold + 1, auc_score))

        total_score += auc_score
        if return_clf: clf_set.append(clf)

    print('Total AUC : %.6f' % (total_score/folds.n_splits))

    if submit!=None:
        submit_data = pd.DataFrame(np.c_[all_data[all_data.TEST==1]['SK_ID_CURR'].values.astype('int32'),sub_preds],
             columns=['SK_ID_CURR','TARGET'])
        submit_data['SK_ID_CURR'] = submit_data['SK_ID_CURR'].astype('int')
        submit_data['TARGET'] = submit_data['TARGET'].astype('float32')
        submit_data.to_csv('csv/'+submit, index=None, float_format='%.8f')

    if return_clf: return clf_set

    return

# %%
# fold - 3

FoldSubmit(merged, index_cols, clf, submit='180720-3.csv')
# Out:
# Training until validation scores don't improve for 150 rounds.
# [100]	training's auc: 0.757115	valid_1's auc: 0.745918
# [200]	training's auc: 0.780941	valid_1's auc: 0.762897
# [300]	training's auc: 0.799216	valid_1's auc: 0.773952
# [400]	training's auc: 0.811926	valid_1's auc: 0.779598
# [500]	training's auc: 0.822103	valid_1's auc: 0.782612
# [600]	training's auc: 0.831156	valid_1's auc: 0.784426
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-ce0e6ca48172> in <module>()
#       1 # fold - 3
#       2 merged = pd.read_pickle('edit/tmp_data/merged.pkl')
# ----> 3 FoldSubmit(merged, index_cols, clf, submit='180720-3.csv')
#
# <ipython-input-21-37bc09953a3e> in FoldSubmit(all_data, index_cols, model, submit, return_clf)
#      37         clf.fit(trn_x, trn_y,
#      38                 eval_set= [(trn_x, trn_y), (val_x.iloc[arrange_inds], val_y.iloc[arrange_inds])],
# ---> 39                 eval_metric='auc', verbose=100, early_stopping_rounds=150
#      40                )
#      41
#
# /Users/sh-tatsuno/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     673                                         verbose=verbose, feature_name=feature_name,
#     674                                         categorical_feature=categorical_feature,
# --> 675                                         callbacks=callbacks)
#     676         return self
#     677
#
# /Users/sh-tatsuno/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     467                               verbose_eval=verbose, feature_name=feature_name,
#     468                               categorical_feature=categorical_feature,
# --> 469                               callbacks=callbacks)
#     470
#     471         if evals_result:
#
# /Users/sh-tatsuno/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     199                                     evaluation_result_list=None))
#     200
# --> 201         booster.update(fobj=fobj)
#     202
#     203         evaluation_result_list = []
#
# /Users/sh-tatsuno/.pyenv/versions/anaconda3-4.4.0/lib/python3.6/site-packages/lightgbm/basic.py in update(self, train_set, fobj)
#    1522             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    1523                 self.handle,
# -> 1524                 ctypes.byref(is_finished)))
#    1525             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    1526             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
run(model = clf, submit='180705.csv')
# Out:
# 100%|██████████| 6/6 [00:28<00:00,  5.53s/it]
# Training until validation scores don't improve for 150 rounds.
# [100]	training's auc: 0
# [800]	training's auc: 0.847286	valid_1's auc: 0.788262
# [900]	training's auc: 0.853666	valid_1's auc: 0.788896
# [1000]	training's auc: 0.860074	valid_1's auc: 0.788995
# [1100]	training's auc: 0.865617	valid_1's auc: 0.789389
# [1200]	training's auc: 0.870743	valid_1's auc: 0.789574
# [1300]	training's auc: 0.875602	valid_1's auc: 0.789592
# [1400]	training's auc: 0.880501	valid_1's auc: 0.789589
# Early stopping, best iteration is:
# [1257]	training's auc: 0.873776	valid_1's auc: 0.789701
# Fold  4 AUC : 0.789701
# Total AUC : 0.789279

# %%
#merged = DataMerger([all_data, buro, cc_bal, inst, pos, prev], 'SK_ID_CURR')
merged.columns[400:500]
# Out:
# Index(['POS_NAME_CONTRACT_STATUS_nan_MEAN', 'POS_COUNT',
#        'PREV_AMT_ANNUITY_MAX', 'PREV_AMT_ANNUITY_MEAN',
#        'PREV_AMT_APPLICATION_MEAN', 'PREV_AMT_CREDIT_MAX',
#        'PREV_AMT_CREDIT_MEAN', 'PREV_APP_CREDIT_PERC_MAX',
#        'PREV_APP_CREDIT_PERC_MEAN', 'PREV_AMT_DOWN_PAYMENT_MAX',
#        'PREV_AMT_DOWN_PAYMENT_MEAN', 'PREV_AMT_GOODS_PRICE_MAX',
#        'PREV_AMT_GOODS_PRICE_MEAN', 'PREV_HOUR_APPR_PROCESS_START_MAX',
#        'PREV_HOUR_APPR_PROCESS_START_MEAN', 'PREV_RATE_DOWN_PAYMENT_MIN',
#        'PREV_RATE_DOWN_PAYMENT_MAX', 'PREV_RATE_DOWN_PAYMENT_MEAN',
#        'PREV_DAYS_DECISION_MIN', 'PREV_DAYS_DECISION_MAX',
#        'PREV_DAYS_DECISION_MEAN', 'PREV_CNT_PAYMENT_MEAN',
#        'PREV_CNT_PAYMENT_SUM', 'PREV_NAME_CONTRACT_TYPE_Cash loans_MEAN',
#        'PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN',
#        'PREV_NAME_CONTRACT_TYPE_Revolving loans_MEAN',
#        'PREV_NAME_CONTRACT_TYPE_XNA_MEAN', 'PREV_NAME_CONTRACT_TYPE_nan_MEAN',
#        'PREV_WEEKDAY_APPR_PROCESS_START_FRIDAY_MEAN',
#        'PREV_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN',
#        'PREV_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN',
#        'PREV_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN',
#        'PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN',
#        'PREV_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN',
#        'PREV_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN',
#        'PREV_WEEKDAY_APPR_PROCESS_START_nan_MEAN',
#        'PREV_FLAG_LAST_APPL_PER_CONTRACT_N_MEAN',
#        'PREV_FLAG_LAST_APPL_PER_CONTRACT_Y_MEAN',
#        'PREV_FLAG_LAST_APPL_PER_CONTRACT_nan_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Building a house or an annex_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Business development_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Buying a garage_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Buying a holiday home / land_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Buying a home_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Buying a new car_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Buying a used car_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Car repairs_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Education_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Everyday expenses_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Furniture_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Gasification / water supply_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Hobby_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Journey_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Medicine_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Money for a third person_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Other_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Payments on other loans_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Purchase of electronic equipment_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Refusal to name the goal_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Repairs_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Urgent needs_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_Wedding / gift / holiday_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_XAP_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_XNA_MEAN',
#        'PREV_NAME_CASH_LOAN_PURPOSE_nan_MEAN',
#        'PREV_NAME_CONTRACT_STATUS_Approved_MEAN',
#        'PREV_NAME_CONTRACT_STATUS_Canceled_MEAN',
#        'PREV_NAME_CONTRACT_STATUS_Refused_MEAN',
#        'PREV_NAME_CONTRACT_STATUS_Unused offer_MEAN',
#        'PREV_NAME_CONTRACT_STATUS_nan_MEAN',
#        'PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN',
#        'PREV_NAME_PAYMENT_TYPE_Cashless from the account of the employer_MEAN',
#        'PREV_NAME_PAYMENT_TYPE_Non-cash from your account_MEAN',
#        'PREV_NAME_PAYMENT_TYPE_XNA_MEAN', 'PREV_NAME_PAYMENT_TYPE_nan_MEAN',
#        'PREV_CODE_REJECT_REASON_CLIENT_MEAN',
#        'PREV_CODE_REJECT_REASON_HC_MEAN', 'PREV_CODE_REJECT_REASON_LIMIT_MEAN',
#        'PREV_CODE_REJECT_REASON_SCO_MEAN',
#        'PREV_CODE_REJECT_REASON_SCOFR_MEAN',
#        'PREV_CODE_REJECT_REASON_SYSTEM_MEAN',
#        'PREV_CODE_REJECT_REASON_VERIF_MEAN',
#        'PREV_CODE_REJECT_REASON_XAP_MEAN', 'PREV_CODE_REJECT_REASON_XNA_MEAN',
#        'PREV_CODE_REJECT_REASON_nan_MEAN',
#        'PREV_NAME_TYPE_SUITE_Children_MEAN',
#        'PREV_NAME_TYPE_SUITE_Family_MEAN',
#        'PREV_NAME_TYPE_SUITE_Group of people_MEAN',
#        'PREV_NAME_TYPE_SUITE_Other_A_MEAN',
#        'PREV_NAME_TYPE_SUITE_Other_B_MEAN',
#        'PREV_NAME_TYPE_SUITE_Spouse, partner_MEAN',
#        'PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN',
#        'PREV_NAME_TYPE_SUITE_nan_MEAN', 'PREV_NAME_CLIENT_TYPE_New_MEAN',
#        'PREV_NAME_CLIENT_TYPE_Refreshed_MEAN',
#        'PREV_NAME_CLIENT_TYPE_Repeater_MEAN', 'PREV_NAME_CLIENT_TYPE_XNA_MEAN',
#        'PREV_NAME_CLIENT_TYPE_nan_MEAN',
#        'PREV_NAME_GOODS_CATEGORY_Additional Service_MEAN',
#        'PREV_NAME_GOODS_CATEGORY_Animals_MEAN'],
#       dtype='object')

# %%
pd.set_option('display.max_columns', 1000)

# %%
np.where(np.array([1,2,1,3]) > 1)[0]
# Out:
# array([1, 3])

# %%
# 0.789586
merged = DataMerger([all_data, buro, cc_bal, inst, pos, prev], 'SK_ID_CURR')
merged['AMT_ANNUITY_RATE_MEAN'] = merged['AMT_ANNUITY'] /merged['PREV_AMT_ANNUITY_MEAN'] 
#merged['AMT_CREDIT_rate'] = merged['AMT_CREDIT'] /merged['PREV_AMT_CREDIT'] 
#merged['AMT_GOODS_PRICE_rate'] = merged['AMT_GOODS_PRICE'] /merged['PREV_AMT_GOODS_PRICE'] 

FoldSubmit(merged, index_cols, model = clf,submit='180705-2.csv')
# Out:
# 100%|██████████| 6/6 [00:30<00:00,  6.00s/it]
# Training until validation scores don't improve for 150 rounds.
# [100]	training's auc: 0.757491	valid_1's auc: 0.757965
# [200]	training's auc: 0.781399	valid_1's auc: 0.773663
# [300]	training's auc: 0.799791	valid_1's auc: 0.784517
# [400]	training's auc: 0.812248	valid_1's auc: 0.78971
# [500]	training's auc: 0.822112	valid_1's auc: 0.792777
# [600]	training's auc: 0.830738	valid_1's auc: 0.794307
# [700]	training's auc: 0.838495	valid_1's auc: 0.795656
# [800]	training's auc: 0.84547	valid_1's auc: 0.796459
# [900]	training's auc: 0.851893	valid_1's auc: 0.797162
# [1000]	training's auc: 0.857895	valid_1's auc: 0.797628
# [1100]	training's auc: 0.863702	valid_1's auc: 0.797964
# [1200]	training's auc: 0.86912	valid_1's auc: 0.798254
# [1300]	training's auc: 0.874235	valid_1's auc: 0.798509
# [1400]	training's auc: 0.879228	valid_1's auc: 0.798604
# [1500]	training's auc: 0.883778	valid_1's auc: 0.79856
# Early stopping, best iteration is:
# [1389]	training's auc: 0.878664	valid_1's auc: 0.798623
# Fold  1 AUC : 0.798623
# Training until validation scores don't improve for 150 rounds.
# [100]	training's auc: 0.759218	valid_1's auc: 0.740214
# [200]	training's auc: 0.783037	valid_1's auc: 0.759532
# [300]	training's auc: 0.801354	valid_1's auc: 0.772186
# [400]	training's auc: 0.813737	valid_1's auc: 0.778326
# [500]	training's auc: 0.82356	valid_1's auc: 0.781815
# [600]	training's auc: 0.832209	valid_1's auc: 0.784021
# [700]	training's auc: 0.839689	valid_1's auc: 0.785122
# [800]	training's auc: 0.846518	valid_1's auc: 0.786029
# [900]	training's auc: 0.85307	valid_1's auc: 0.78677
# [1000]	training's auc: 0.859062	valid_1's auc: 0.787243
# [1100]	training's auc: 0.864544	valid_1's auc: 0.787735
# [1200]	training's auc: 0.869721	valid_1's auc: 0.788275
# [1300]	training's auc: 0.874928	valid_1's auc: 0.788595
# [1400]	training's auc: 0.879829	valid_1's auc: 0.78869
# [1500]	training's auc: 0.88445	valid_1's auc: 0.78877
# [1600]	training's auc: 0.889001	valid_1's auc: 0.788791
# [1700]	training's auc: 0.893123	valid_1's auc: 0.788918
# [1800]	training's auc: 0.897232	valid_1's auc: 0.788999
# [1900]	training's auc: 0.901007	valid_1's auc: 0.789193
# [2000]	training's auc: 0.904874	valid_1's auc: 0.789083
# Early stopping, best iteration is:
# [1935]	training's auc: 0.902384	valid_1's auc: 0.789257
# Fold  2 AUC : 0.789257
# Training until validation scores don't improve for 150 rounds.
# [100]	training's auc: 0.
# [800]	training's auc: 0.845786	valid_1's auc: 0.785766
# [900]	training's auc: 0.852102	valid_1's auc: 0.786561
# [1000]	training's auc: 0.858029	valid_1's auc: 0.787437
# [1100]	training's auc: 0.863596	valid_1's auc: 0.787805
# [1200]	training's auc: 0.868952	valid_1's auc: 0.788148
# [1300]	training's auc: 0.873733	valid_1's auc: 0.788446
# [1400]	training's auc: 0.878717	valid_1's auc: 0.788562
# [1500]	training's auc: 0.883324	valid_1's auc: 0.788735
# [1600]	training's auc: 0.887732	valid_1's auc: 0.788728
# [1700]	training's auc: 0.892005	valid_1's auc: 0.788729
# Early stopping, best iteration is:
# [1621]	training's auc: 0.888669	valid_1's auc: 0.788819
# Fold  4 AUC : 0.788819
# Total AUC : 0.790376

# %%
# 0.789586
merged = DataMerger([all_data, buro, cc_bal, inst, pos, prev], 'SK_ID_CURR')
#merged['AMT_ANNUITY_RATE_MEAN'] = merged['AMT_ANNUITY'] /merged['PREV_AMT_ANNUITY_MAX'] 
#merged['AMT_CREDIT_rate'] = merged['AMT_CREDIT'] /merged['PREV_AMT_CREDIT'] 
merged['AMT_GOODS_PRICE_rate'] = merged['AMT_GOODS_PRICE'] /merged['PREV_AMT_GOODS_PRICE_MAX'] 

FoldSubmit(merged, index_cols)

# %%
# 0.789586
index_cols = ['SK_ID_CURR','TEST','TARGET']
buro = pd.read_pickle('edit/tmp_data/buro.pkl')

merged = DataMerger([all_data, buro, cc_bal, inst, pos, prev], 'SK_ID_CURR')
merged['AMT_ANNUITY_rate'] = merged['AMT_ANNUITY_x'] /merged['AMT_ANNUITY_y'] 
merged['AMT_CREDIT_rate'] = merged['AMT_CREDIT_x'] /merged['AMT_CREDIT_y'] 
merged['AMT_GOODS_PRICE_rate'] = merged['AMT_GOODS_PRICE_x'] /merged['AMT_GOODS_PRICE_y'] 

clf_set = FoldSubmit(merged, index_cols,return_clf=True)
# Out:
# 100%|██████████| 6/6 [00:08<00:00,  1.44s/it]
# Training until validation scores don't improve for 150 rounds.
# [100]	training's auc: 0.764246	valid_1's auc: 0.762301
# [200]	training's auc: 0.795982	valid_1's auc: 0.783074
# [300]	training's auc: 0.815063	valid_1's auc: 0.790463
# Did not meet early stopping. Best iteration is:
# [300]	training's auc: 0.815063	valid_1's auc: 0.790463
# Fold  1 AUC : 0.790463
# Training until validation scores don't improve for 150 rounds.
# [100]	training's auc: 0.767546	valid_1's auc: 0.745799
# [200]	training's auc: 0.798402	valid_1's auc: 0.768883
# [300]	training's auc: 0.817315	valid_1's auc: 0.777389
# Did not meet early stopping. Best iteration is:
# [300]	training's auc: 0.817315	valid_1's auc: 0.777389
# Fold  2 AUC : 0.777389
# Training until validation scores don't improve for 150 rounds.
# [100]	training's auc: 0.765021	valid_1's auc: 0.745166
# [200]	training's auc: 0.797105	valid_1's auc: 0.766359
# [300]	training's auc: 0.815552	valid_1's auc: 0.773943
# Did not meet early stopping. Best iteration is:
# [300]	training's auc: 0.815552	valid_1's auc: 0.773943
# Fold  3 AUC : 0.773943
# Training until validation scores don't improve for 150 rounds.
# [100]	training's auc: 0.765249	valid_1's auc: 0.749396
# [200]	training's auc: 0.798659	valid_1's auc: 0.771134
# [300]	training's auc: 0.817691	valid_1's auc: 0.778765
# Did not meet early stopping. Best iteration is:
# [300]	training's auc: 0.817691	valid_1's auc: 0.778765
# Fold  4 AUC : 0.778765
# Total AUC : 0.780140

# %%
# 0.789586
index_cols = ['SK_ID_CURR','TEST','TARGET']
cc_bal = pd.read_pickle('edit/tmp_data/cc_bal.pkl')
pos = pd.read_pickle('edit/tmp_data/pos.pkl')
inst = pd.read_pickle('edit/tmp_data/inst.pkl')
all_data = pd.read_pickle('edit/tmp_data/all_data.pkl')

merged = DataMerger([all_data, buro, cc_bal, inst, pos, prev], 'SK_ID_CURR')
merged['AMT_ANNUITY_rate'] = merged['AMT_ANNUITY_x'] /merged['AMT_ANNUITY_y'] 
merged['AMT_CREDIT_rate'] = merged['AMT_CREDI
# Training until validation scores don't improve for 150 rounds.
# [100]	training's auc: 0.759649	valid_1's auc: 0.743455
# [200]	training's auc: 0.786972	valid_1's auc: 0.760783
# [300]	training's auc: 0.806998	valid_1's auc: 0.771879
# [400]	training's auc: 0.820991	valid_1's auc: 0.777136
# [500]	training's auc: 0.833393	valid_1's auc: 0.780365
# [600]	training's auc: 0.844448	valid_1's auc: 0.78219
# [700]	training's auc: 0.854384	valid_1's auc: 0.783116
# [800]	training's auc: 0.863855	valid_1's auc: 0.783922
# [900]	training's auc: 0.872343	valid_1's auc: 0.784179
# [1000]	training's auc: 0.88019	valid_1's auc: 0.784487
# [1100]	training's auc: 0.887372	valid_1's auc: 0.784714
# [1200]	training's auc: 0.894277	valid_1's auc: 0.784946
# [1300]	training's auc: 0.90071	valid_1's auc: 0.784901
# Early stopping, best iteration is:
# [1227]	training's auc: 0.896018	valid_1's auc: 0.785104
# Fold  4 AUC : 0.785104
# Total AUC : 0.786212

# %%
# 0.789586
index_cols = ['SK_ID_CURR','TEST','TARGET']
cc_bal = pd.read_pickle('edit/tmp_data/cc_bal.pkl')
pos = pd.read_pickle('edit/tmp_data/pos.pkl')
inst = pd.read_pickle('edit/tmp_data/inst.pkl')
all_data = pd.read_pickle('edit/tmp_data/all_data.pkl')

merged = DataMerger([all_data, buro, cc_bal, inst, pos, prev], 'SK_ID_CURR')
merged['AMT_ANNUITY_rate'] = merged['AMT_ANNUITY_x'] /merged['AMT_ANNUITY_y'] 
merged['AMT_CREDIT_rate'] = merged['AMT_CREDIT_x'] /merged['AMT_CREDIT_y'] 
merged['AMT_GOODS_PRICE_rate'] = merged['AMT_GOODS_PRICE_x'] /merged['AMT_GOODS_PRICE_y'] 

clf_set = FoldSubmit(merged, index_cols, model=clf, submit='180618.csv',return_clf=True)
# Out:
# 100%|██████████| 6/6 [00:12<00:00,  1.93s/it]
# Training until validation scores don't improve for 150 rounds.
# [100]	training's auc: 0.757972	valid_1's auc: 0.748203
# [200]	training's auc: 0.782353	valid_1's auc: 0.762715
# [300]	training's auc: 0.801223	valid_1's auc: 0.773366
# [400]	training's auc: 0.81374	valid_1's auc: 0.778345
# [500]	training's auc: 0.823949	valid_1's auc: 0.781248
# [600]	training's auc: 0.8326	valid_1's auc: 0.783197
# [700]	training's auc: 0.840151	valid_1's auc: 0.784301
# [800]	training's auc: 0.846925	valid_1's auc: 0.784888
# [900]	training's auc: 0.853499	valid_1's auc: 0.78562
# [1000]	training's auc: 0.859743	valid_1's auc: 0.785689
# [1100]	training's auc: 0.865634	valid_1's auc: 0.785988
# [1200]	training's auc: 0.871095	valid_1's auc: 0.786509
# [1300]	training's auc: 0.87647	valid_1's auc: 0.786764
# [1400]	training's auc: 0.881555	valid_1's auc: 0.786882
# [1500]	training's auc: 0.886324	valid_1's auc: 0.786888
# [1600]	training's auc: 0.891015	valid_1's auc: 0.78689
# Early stopping, best iteration is:
# [1528]	training's auc: 0.88761	valid_1's auc: 0.787032
# Fold  1 AUC : 0.787032
# Training until validation scores don't improve for 150 rounds.
# [100]	training's auc: 0.760065	valid_1's auc: 0.744151
# [200]	training's auc: 0.783769	valid_1's auc: 0.759584
# [300]	training's auc: 0.802293	valid_1's auc: 0.77034
# [400]	training's auc: 0.814773	valid_1's auc: 0.775955
# [500]	training's auc: 0.824352	valid_1's auc: 0.778782
# [600]	training's auc: 0.832853	valid_1's auc: 0.78083
# [700]	training's auc: 0.840364	valid_1's auc: 0.78212
# [800]	training's auc: 0.847314	valid_1's auc: 0.783044
# [900]	training's auc: 0.853891	valid_1's auc: 0.783571
pos = pd.read_pickle('edit/tmp_data/pos.pkl')
inst = pd.read_pickle('edit/tmp_data/inst.pkl')
bburo = pd.read_pickle('edit/tmp_data/buroX.pkl')
all_data = pd.read_pickle('edit/tmp_data/all_data.pkl')

merged = DataMerger([all_data, buro, cc_bal, inst, pos, prev], 'SK_ID_CURR')
merged['AMT_ANNUITY_rate'] = merged['AMT_ANNUITY_x'] /merged['AMT_ANNUITY_y'] 
merged['AMT_CREDIT_rate'] = merged['AMT_CREDIT_x'] /merged['AMT_CREDIT_y'] 
merged['AMT_GOODS_PRICE_rate'] = merged['AMT_GOODS_PRICE_x'] /merged['AMT_GOODS_PRICE_y'] 

clf_set = FoldSubmit(merged, index_cols, model=clf, submit='180614.csv',return_clf=True)

# %%
fdf = pd.DataFrame(np.c_[np.array(merged.drop(index_cols,axis=1).columns),clf_set[2].feature_importances_.tolist()], columns=['feature','score']).sort_values('score',ascending=False)

# %%
fdf.head()
# Out:
#                    feature score
# 37            EXT_SOURCE_2  1136
# 38            EXT_SOURCE_3  1066
# 110         ANNUITY LENGTH  1009
# 22              DAYS_BIRTH   777
# 374  CNT_INSTALMENT_FUTURE   759

# %%
fdf[fdf.score>200]['feature'].values
# Out:
# array(['EXT_SOURCE_2', 'EXT_SOURCE_3', 'ANNUITY LENGTH', 'DAYS_BIRTH',
#        'CNT_INSTALMENT_FUTURE', 'EXT_SOURCE_1p2', 'EXT_SOURCE_1',
#        'max_buro_DAYS_CREDIT', 'AMT_ANNUITY_x', 'SK_DPD_DEF_y',
#        'AMT_PAYMENT', 'DAYS_ID_PUBLISH', 'AMT_ANNUITY_rate',
#        'SK_ID_CURR_CNT_POS_CASH', 'CNT_PAYMENT', 'AMT_GOODS_PRICE_x',
#        'max_buro_DAYS_CREDIT_ENDDATE', 'AMT_CREDIT_x',
#        'DAYS_LAST_DUE_1ST_VERSION', 'ANNUITY_INCOME_RATIO',
#        'WORKING_LIFE_RATIO', 'max_buro_DAYS_ENDDATE_FACT',
#        'DAYS_REGISTRATION', 'AMT_DOWN_PAYMENT', 'DAYS_EMPLOYED',
#        'med_buro_AMT_CREDIT_SUM', 'med_buro_DAYS_CREDIT_ENDDATE',
#        'NAME_CONTRACT_STATUS_Refused', 'OWN_CAR_AGE', 'EXT_SOURCE_12',
#        'CODE_GENDER', 'CNT_DRAWINGS_CURRENT', 'DAYS_LAST_PHONE_CHANGE',
#        'CNT_INSTALMENT', 'avg_buro_AMT_CREDIT_SUM_DEBT',
#        'ORGANIZATION_TYPE', 'SK_ID_PREV_y', 'REGION_POPULATION_RELATIVE',
#        'HOUR_APPR_PROCESS_START_y', 'min_buro_AMT_CREDIT_SUM',
#        'RATE_DOWN_PAYMENT', 'NUM_INSTALMENT_VERSION',
#        'NAME_YIELD_GROUP_high', 'NUM_INSTALMENT_NUMBER',
#        'max_buro_AMT_CREDIT_SUM', 'AMT_ANNUITY_y',
#        'CNT_DRAWINGS_ATM_CURRENT', 'SK_DPD_y', 'SELLERPLACE_AREA',
#        'med_buro_DAYS_CREDIT'], dtype=object)

# %%
# base model
clf = LGBMClassifier(
            nthread=4,
            n_estimators=10000,
            learning_rate=0.03,
            num_leaves=34,
            colsample_bytree=0.9497036,
            subsample=0.8715623,
            max_depth=8,
            reg_alpha=0.041545473,
            reg_lambda=0.0735294,
# [200]	training's auc: 0.757693	valid_1's auc: 0.743079
# [300]	training's auc: 0.771378	valid_1's auc: 0.753181
# [400]	training's auc: 0.783798	valid_1's auc: 0.76179
# [500]	training's auc: 0.796505	valid_1's auc: 0.769798
# [600]	training's auc: 0.802817	valid_1's auc: 0.772582
# [700]	training's auc: 0.809019	valid_1's auc: 0.775684
# [800]	training's auc: 0.814067	valid_1's auc: 0.778288
# [900]	training's auc: 0.819456	valid_1's auc: 0.78028
# [1000]	training's auc: 0.824092	valid_1's auc: 0.781719
# [1100]	training's auc: 0.828585	valid_1's auc: 0.78281
# [1200]	training's auc: 0.831829	valid_1's auc: 0.783406
# [1300]	training's auc: 0.835404	valid_1's auc: 0.784159
# [1400]	training's auc: 0.839449	valid_1's auc: 0.784857
# [1500]	training's auc: 0.842589	valid_1's auc: 0.784869
# [1600]	training's auc: 0.845862	valid_1's auc: 0.785269
# [1700]	training's auc: 0.849635	valid_1's auc: 0.78577
# [1800]	training's auc: 0.853304	valid_1's auc: 0.786
# [1900]	training's auc: 0.856968	valid_1's auc: 0.786293
# [2000]	training's auc: 0.859912	valid_1's auc: 0.78645
# [2100]	training's auc: 0.863535	valid_1's auc: 0.786686
# [2200]	training's auc: 0.866571	valid_1's auc: 0.787005
# [2300]	training's auc: 0.870206	valid_1's auc: 0.786906
# [2400]	training's auc: 0.874013	valid_1's auc: 0.787202
# [2500]	training's auc: 0.877306	valid_1's auc: 0.787533
# [2600]	training's auc: 0.880293	valid_1's auc: 0.787608
# [2700]	training's auc: 0.883083	valid_1's auc: 0.787537
# Early stopping, best iteration is:
# [2642]	training's auc: 0.881522	valid_1's auc: 0.787638
# Fold  4 AUC : 0.787556
# Total AUC : 0.790583
# [LGBMClassifier(boosting_type='dart', class_weight=None,
#          colsample_bytree=0.9497036, learning_rate=0.03, max_depth=8,
#          min_child_samples=20, min_child_weight=39.3259775,
#          min_split_gain=0.0222415, n_estimators=10000, n_jobs=-1, nthread=4,
#          num_leaves=34, objective=None, random_state=None,
#          reg_alpha=0.041545473, reg_lambda=0.0735294, silent=-1,
#          subsample=0.8715623, subsample_for_bin=200000, subsample_freq=1,
#          verbose=-1), LGBMClassifier(boosting_type='dart', class_weight=None,
#          colsample_bytree=0.9497036, learning_rate=0.03, max_depth=8,
#          min_child_samples=20, min_child_weight=39.3259775,
#          min_split_gain=0.0222415, n_estimators=10000, n_jobs=-1, nthread=4,
#          num_leaves=34, objective=None, random_state=None,
#          reg_alpha=0.041545473, reg_lambda=0.0735294, silent=-1,
#          subsample=0.8715623, subsample_for_bin=200000, subsample_freq=1,
#          verbose=-1), LGBMClassifier(boosting_type='dart', class_weight=None,
#          colsample_bytree=0.9497036, learning_rate=0.03, max_depth=8,
#          min_child_samples=20, min_child_weight=39.3259775,
#          min_split_gain=0.0222415, n_estimators=10000, n_jobs=-1, nthread=4,
#          num_leaves=34, objective=None, random_state=None,
#          reg_alpha=0.041545473, reg_lambda=0.0735294, silent=-1,
#          subsample=0.8715623, subsample_for_bin=200000, subsample_freq=1,
#          verbose=-1), LGBMClassifier(boosting_type='dart', class_weight=None,
#          colsample_bytree=0.9497036, learning_rate=0.03, max_depth=8,
#          min_child_samples=20, min_child_weight=39.3259775,
#          min_split_gain=0.0222415, n_estimators=10000, n_jobs=-1, nthread=4,
#          num_leaves=34, objective=None, random_state=None,
#          reg_alpha=0.041545473, reg_lambda=0.0735294, silent=-1,
#          subsample=0.8715623, subsample_for_bin=200000, subsample_freq=1,
#          verbose=-1)]
